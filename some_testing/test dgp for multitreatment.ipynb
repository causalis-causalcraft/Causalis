# %%
from causalis.scenarios.multi_uncofoundedness.dgp import generate_multitreatment_irm_26

# %%
df = generate_multitreatment_irm_26(return_causal_data=False, include_oracle = True)

# %%
df.head()
# Out:
#            y  t_0  t_1  t_2  tenure_months  avg_sessions_week  \
# 0   8.187885  0.0  0.0  1.0      27.656605           5.352554
# 1  10.443114  0.0  1.0  0.0      11.520191           6.798247
# 2   5.279322  0.0  0.0  1.0      33.005414           2.055459
# 3   4.540659  1.0  0.0  0.0      35.286777           4.429404
# 4   7.530050  0.0  1.0  0.0       0.587578           6.658307
#
#    spend_last_month  premium_user  urban_resident     m_t_0  ...  m_obs_t_1  \
# 0         13.490207           1.0             0.0  0.454071  ...   0.275678
# 1        133.811334           0.0             1.0  0.463188  ...   0.232951
# 2         56.946701           0.0             1.0  0.594286  ...   0.206445
# 3         34.967755           0.0             1.0  0.543398  ...   0.245938
# 4         47.875735           0.0             1.0  0.507310  ...   0.155799
#
#    tau_link_t_1     m_t_2  m_obs_t_2  tau_link_t_2     g_t_0     g_t_1  \
# ...
